# %% [markdown]
# <h2 style='color:blue' align='center'>Influencer Image Classification<h2>

# %% [markdown]
# Special thanks to Debjyoti Paul (My data scientist friend at Amazon) for help with this project

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h3 style='color:purple'>(1) Preprocessing: Detect face and eyes</h3>

# %% [markdown]
# #### When we look at any image, most of the time we identify a person using a face. An image might contain multiple faces, also the face can be obstructed and not clear. The first step in our pre-processing pipeline is to detect faces from an image. Once face is detected, we will detect eyes, if two eyes are detected then only we keep that image otherwise discard it.</h4>

# %% [markdown]
# #### Now how do you detect face and eyes?

# %% [markdown]
# We will use haar cascade from opencv for this. Here is an article on this: https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_objdetect/py_face_detection/py_face_detection.html?highlight=haar

# %%
img = cv2.imread('./images_dataset/ronaldo/ronaldo2.jpg')
img.shape
# Out:
# (1839, 2758, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (1839, 2758)

# %%
gray
# Out:
# array([[130, 131, 131, ...,  79,  79,  78],
#        [131, 131, 131, ...,  79,  80,  80],
#        [132, 132, 132, ...,  79,  80,  81],
#        ...,
#        [104, 106, 106, ...,  80,  80,  81],
#        [102, 105, 106, ...,  80,  80,  81],
#        [102, 106, 107, ...,  79,  80,  80]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')

eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[795, 270, 850, 850]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (795, 270, 850, 850)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %% [markdown]
# <h3 style='color:purple'>(2) Preprocessing: Crop the facial region of the image</h3>

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (850, 850, 3)

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Use wavelet transform as a feature for traning our model</h3>

# %% [markdown]
# #### In wavelet transformed image, you can see edges clearly and that can give us clues on various facial features such as eyes, nose, lips etc

# %% [markdown]
# ### Wavelet transform

# %%
pip install pywavelets
# Out:
# Requirement already satisfied: pywavelets in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from pywavelets) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %% [markdown]
# #### You can see above a wavelet transformed image that gives clues on facial features such as eyes, nose, lips etc. This along with raw pixel image can be used as an input for our classifier

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Load image, detect face. If eyes >=2, then save and crop the face region</h3>

# %% [markdown]
# ####  Lets write a python function that can take input image and returns cropped image (if face and eyes >=2 are detected)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: Image not loaded! Check the file path.{image_path}")
    else:
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  # Now safe to convert
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./images_dataset/ronaldo/ronaldo2.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./images_dataset/ronaldo/ronaldo2.jpg')
plt.imshow(cropped_image)

# %% [markdown]
# **In below image face is not very clear and it doesn't have two eyes clearly visible**

# %%
org_image_obstructed = cv2.imread('./images_dataset/ronaldo/ronaldo2.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./images_dataset/ronaldo/ronaldo2.jpg')
cropped_image_no_2_eyes
# Out:
# array([[[ 39,  38, 100],
#         [ 37,  36,  98],
#         [ 36,  35,  97],
#         ...,
#         [ 31,  29,  29],
#         [ 30,  28,  28],
#         [ 28,  28,  28]],
#
#        [[ 39,  38, 100],
#         [ 37,  36,  98],
#         [ 35,  34,  96],
#         ...,
#         [ 33,  28,  29],
#         [ 30,  28,  28],
#         [ 29,  27,  27]],
#
#        [[ 38,  37, 101],
#         [ 35,  34,  98],
#         [ 34,  33,  97],
#         ...,
#         [ 39,  33,  34],
#         [ 39,  34,  35],
#         [ 36,  31,  32]],
#
#        ...,
#
#        [[115,  47,  40],
#         [115,  48,  39],
#         [115,  48,  39],
#         ...,
#         [133, 148, 194],
#         [133, 148, 194],
#         [136, 152, 195]],
#
#        [[115,  47,  40],
#         [115,  48,  39],
#         [115,  48,  39],
#         ...,
#         [137, 152, 198],
#         [137, 152, 198],
#         [137, 153, 196]],
#
#        [[115,  47,  40],
#         [115,  48,  39],
#         [115,  48,  39],
#         ...,
#         [138, 153, 199],
#         [137, 152, 198],
#         [135, 151, 194]]], dtype=uint8)

# %% [markdown]
# **Above cropped_image_no_2_eyes is None which means we should ignore this image and we will not use such image for model training**

# %%
path_to_data = "./images_dataset/"
path_to_cr_data = "./images_dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./images_dataset/cropped',
#  './images_dataset/elonmusk',
#  './images_dataset/jackma',
#  './images_dataset/ronaldo',
#  './images_dataset/shakira',
#  './images_dataset/vijay']

# %% [markdown]
# **Go through all images in dataset folder and create cropped images for them. There will be cropped folder inside dataset folder after you run this code**

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
influencer_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    influencer_name = img_dir.split('/')[-1]
    influencer_file_names_dict[influencer_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + influencer_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = influencer_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            influencer_file_names_dict[influencer_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./images_dataset/cropped/elonmusk
# Generating cropped images in folder:  ./images_dataset/cropped/jackma
# Generating cropped images in folder:  ./images_dataset/cropped/ronaldo
# Generating cropped images in folder:  ./images_dataset/cropped/shakira
# Generating cropped images in folder:  ./images_dataset/cropped/vijay

# %% [markdown]
# ### Now you should have cropped folder under datasets folder that contains cropped images

# %% [markdown]
# ### Manually examine cropped folder and delete any unwanted images

# %%
influencer_file_names_dict = {}
for img_dir in cropped_image_dirs:
    influencer_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    influencer_file_names_dict[influencer_name] = file_list
influencer_file_names_dict
# Out:
# {'elonmusk': ['./images_dataset/cropped/elonmusk\\elonmusk1.png',
#   './images_dataset/cropped/elonmusk\\elonmusk10.png',
#   './images_dataset/cropped/elonmusk\\elonmusk11.png',
#   './images_dataset/cropped/elonmusk\\elonmusk12.png',
#   './images_dataset/cropped/elonmusk\\elonmusk13.png',
#   './images_dataset/cropped/elonmusk\\elonmusk14.png',
#   './images_dataset/cropped/elonmusk\\elonmusk15.png',
#   './images_dataset/cropped/elonmusk\\elonmusk16.png',
#   './images_dataset/cropped/elonmusk\\elonmusk17.png',
#   './images_dataset/cropped/elonmusk\\elonmusk18.png',
#   './images_dataset/cropped/elonmusk\\elonmusk19.png',
#   './images_dataset/cropped/elonmusk\\elonmusk2.png',
#   './images_dataset/cropped/elonmusk\\elonmusk20.png',
#   './images_dataset/cropped/elonmusk\\elonmusk21.png',
#   './images_dataset/cropped/elonmusk\\elonmusk22.png',
#   './images_dataset/cropped/elonmusk\\elonmusk23.png',
#   './images_dataset/cropped/elonmusk\\elonmusk24.png',
#   './images_dataset/cropped/elonmusk\\elonmusk25.png',
#   './images_dataset/cropped/elonmusk\\elonmusk26.png',
#   './images_dataset/cropped/elonmusk\\elonmusk27.png',
#   './images_dataset/cropped/elonmusk\\elonmusk28.png',
#   './images_dataset/cropped/elonmusk\\elonmusk29.png',
#   './images_dataset/cropped/elonmusk\\elonmusk3.png',
#   './images_dataset/cropped/elonmusk\\elonmusk30.png',
#   './images_dataset/cropped/elonmusk\\elonmusk31.png',
#   './images_dataset/cropped/elonmusk\\elonmusk32.png',
#   './images_dataset/cropped/elonmusk\\elonmusk33.png',
#   './images_dataset/cropped/elonmusk\\elonmusk34.png',
#   './images_dataset/cropped/elonmusk\\elonmusk35.png',
#   './images_dataset/cropped/elonmusk\\elonmusk36.png',
#   './images_dataset/cropped/elonmusk\\elonmusk37.png',
#   './images_dataset/cropped/elonmusk\\elonmusk38.png',
#   './images_dataset/cropped/elonmusk\\elonmusk39.png',
#   './images_dataset/cropped/elonmusk\\elonmusk4.png',
#   './images_dataset/cropped/elonmusk\\elonmusk40.png',
#   './images_dataset/cropped/elonmusk\\elonmusk41.png',
#   './images_dataset/cropped/elonmusk\\elonmusk42.png',
#   './images_dataset/cropped/elonmusk\\elonmusk43.png',
#   './images_dataset/cropped/elonmusk\\elonmusk44.png',
#   './images_dataset/cropped/elonmusk\\elonmusk45.png',
#   './images_dataset/cropped/elonmusk\\elonmusk46.png',
#   './images_dataset/cropped/elonmusk\\elonmusk47.png',
#   './images_dataset/cropped/elonmusk\\elonmusk48.png',
#   './images_dataset/cropped/elonmusk\\elonmusk49.png',
#   './images_dataset/cropped/elonmusk\\elonmusk5.png',
#   './images_dataset/cropped/elonmusk\\elonmusk50.png',
#   './images_dataset/cropped/elonmusk\\elonmusk51.png',
#   './images_dataset/cropped/elonmusk\\elonmusk52.png',
#   './images_dataset/cropped/elonmusk\\elonmusk53.png',
#   './images_dataset/cropped/elonmusk\\elonmusk54.png',
#   './images_dataset/cropped/elonmusk\\elonmusk55.png',
#   './images_dataset/cropped/elonmusk\\elonmusk56.png',
#   './images_dataset/cropped/elonmusk\\elonmusk57.png',
#   './images_dataset/cropped/elonmusk\\elonmusk58.png',
#   './images_dataset/cropped/elonmusk\\elonmusk59.png',
#   './images_dataset/cropped/elonmusk\\elonmusk6.png',
#   './images_dataset/cropped/elonmusk\\elonmusk60.png',
#   './images_dataset/cropped/elonmusk\\elonmusk61.png',
#   './images_dataset/cropped/elonmusk\\elonmusk62.png',
#   './images_dataset/cropped/elonmusk\\elonmusk63.png',
#   './images_dataset/cropped/elonmusk\\elonmusk64.png',
#   './images_dataset/cropped/elonmusk\\elonmusk65.png',
#   './images_dataset/cropped/elonmusk\\elonmusk66.png',
#   './images_dataset/cropped/elonmusk\\elonmusk67.png',
#   './images_dataset/cropped/elonmusk\\elonmusk68.png',
#   './images_dataset/cropped/elonmusk\\elonmusk69.png',
#   './images_dataset/cropped/elonmusk\\elonmusk7.png',
#   './images_dataset/cropped/elonmusk\\elonmusk70.png',
#   './images_dataset/cropped/elonmusk\\elonmusk71.png',
#   './images_dataset/cropped/elonmusk\\elonmusk72.png',
#   './images_dataset/cropped/elonmusk\\elonmusk73.png',
#   './images_dataset/cropped/elonmusk\\elonmusk74.png',
#   './images_dataset/cropped/elonmusk\\elonmusk75.png',
#   './images_dataset/cropped/elonmusk\\elonmusk76.png',
#   './images_dataset/cropped/elonmusk\\elonmusk77.png',
#   './images_dataset/cropped/elonmusk\\elonmusk8.png',
#   './images_dataset/cropped/elonmusk\\elonmusk9.png'],
#  'jackma': ['./images_dataset/cropped/jackma\\jackma1.png',
#   './images_dataset/cropped/jackma\\jackma10.png',
#   './images_dataset/cropped/jackma\\jackma11.png',
#   './images_dataset/cropped/jackma\\jackma12.png',
#   './images_dataset/cropped/jackma\\jackma13.png',
#   './images_dataset/cropped/jackma\\jackma14.png',
#   './images_dataset/cropped/jackma\\jackma15.png',
#   './images_dataset/cropped/jackma\\jackma16.png',
#   './images_dataset/cropped/jackma\\jackma17.png',
#   './images_dataset/cropped/jackma\\jackma18.png',
#   './images_dataset/cropped/jackma\\jackma19.png',
#   './images_dataset/cropped/jackma\\jackma2.png',
#   './images_dataset/cropped/jackma\\jackma20.png',
#   './images_dataset/cropped/jackma\\jackma21.png',
#   './images_dataset/cropped/jackma\\jackma22.png',
#   './images_dataset/cropped/jackma\\jackma23.png',
#   './images_dataset/cropped/jackma\\jackma24.png',
#   './images_dataset/cropped/jackma\\jackma25.png',
#   './images_dataset/cropped/jackma\\jackma26.png',
#   './images_dataset/cropped/jackma\\jackma27.png',
#   './images_dataset/cropped/jackma\\jackma28.png',
#   './images_dataset/cropped/jackma\\jackma29.png',
#   './images_dataset/cropped/jackma\\jackma3.png',
#   './images_dataset/cropped/jackma\\jackma30.png',
#   './images_dataset/cropped/jackma\\jackma31.png',
#   './images_dataset/cropped/jackma\\jackma32.png',
#   './images_dataset/cropped/jackma\\jackma33.png',
#   './images_dataset/cropped/jackma\\jackma34.png',
#   './images_dataset/cropped/jackma\\jackma35.png',
#   './images_dataset/cropped/jackma\\jackma36.png',
#   './images_dataset/cropped/jackma\\jackma37.png',
#   './images_dataset/cropped/jackma\\jackma38.png',
#   './images_dataset/cropped/jackma\\jackma39.png',
#   './images_dataset/cropped/jackma\\jackma4.png',
#   './images_dataset/cropped/jackma\\jackma40.png',
#   './images_dataset/cropped/jackma\\jackma41.png',
#   './images_dataset/cropped/jackma\\jackma42.png',
#   './images_dataset/cropped/jackma\\jackma43.png',
#   './images_dataset/cropped/jackma\\jackma44.png',
#   './images_dataset/cropped/jackma\\jackma45.png',
#   './images_dataset/cropped/jackma\\jackma46.png',
#   './images_dataset/cropped/jackma\\jackma47.png',
#   './images_dataset/cropped/jackma\\jackma48.png',
#   './images_dataset/cropped/jackma\\jackma49.png',
#   './images_dataset/cropped/jackma\\jackma5.png',
#   './images_dataset/cropped/jackma\\jackma50.png',
#   './images_dataset/cropped/jackma\\jackma51.png',
#   './images_dataset/cropped/jackma\\jackma52.png',
#   './images_dataset/cropped/jackma\\jackma53.png',
#   './images_dataset/cropped/jackma\\jackma54.png',
#   './images_dataset/cropped/jackma\\jackma55.png',
#   './images_dataset/cropped/jackma\\jackma56.png',
#   './images_dataset/cropped/jackma\\jackma57.png',
#   './images_dataset/cropped/jackma\\jackma58.png',
#   './images_dataset/cropped/jackma\\jackma59.png',
#   './images_dataset/cropped/jackma\\jackma6.png',
#   './images_dataset/cropped/jackma\\jackma7.png',
#   './images_dataset/cropped/jackma\\jackma8.png',
#   './images_dataset/cropped/jackma\\jackma9.png'],
#  'ronaldo': ['./images_dataset/cropped/ronaldo\\ronaldo1.png',
#   './images_dataset/cropped/ronaldo\\ronaldo10.png',
#   './images_dataset/cropped/ronaldo\\ronaldo11.png',
#   './images_dataset/cropped/ronaldo\\ronaldo12.png',
#   './images_dataset/cropped/ronaldo\\ronaldo13.png',
#   './images_dataset/cropped/ronaldo\\ronaldo14.png',
#   './images_dataset/cropped/ronaldo\\ronaldo15.png',
#   './images_dataset/cropped/ronaldo\\ronaldo16.png',
#   './images_dataset/cropped/ronaldo\\ronaldo17.png',
#   './images_dataset/cropped/ronaldo\\ronaldo18.png',
#   './images_dataset/cropped/ronaldo\\ronaldo19.png',
#   './images_dataset/cropped/ronaldo\\ronaldo2.png',
#   './images_dataset/cropped/ronaldo\\ronaldo20.png',
#   './images_dataset/cropped/ronaldo\\ronaldo21.png',
#   './images_dataset/cropped/ronaldo\\ronaldo22.png',
#   './images_dataset/cropped/ronaldo\\ronaldo23.png',
#   './images_dataset/cropped/ronaldo\\ronaldo24.png',
#   './images_dataset/cropped/ronaldo\\ronaldo25.png',
#   './images_dataset/cropped/ronaldo\\ronaldo26.png',
#   './images_dataset/cropped/ronaldo\\ronaldo27.png',
#   './images_dataset/cropped/ronaldo\\ronaldo28.png',
#   './images_dataset/cropped/ronaldo\\ronaldo29.png',
#   './images_dataset/cropped/ronaldo\\ronaldo3.png',
#   './images_dataset/cropped/ronaldo\\ronaldo30.png',
#   './images_dataset/cropped/ronaldo\\ronaldo31.png',
#   './images_dataset/cropped/ronaldo\\ronaldo32.png',
#   './images_dataset/cropped/ronaldo\\ronaldo33.png',
#   './images_dataset/cropped/ronaldo\\ronaldo34.png',
#   './images_dataset/cropped/ronaldo\\ronaldo35.png',
#   './images_dataset/cropped/ronaldo\\ronaldo36.png',
#   './images_dataset/cropped/ronaldo\\ronaldo37.png',
#   './images_dataset/cropped/ronaldo\\ronaldo38.png',
#   './images_dataset/cropped/ronaldo\\ronaldo39.png',
#   './images_dataset/cropped/ronaldo\\ronaldo4.png',
#   './images_dataset/cropped/ronaldo\\ronaldo40.png',
#   './images_dataset/cropped/ronaldo\\ronaldo41.png',
#   './images_dataset/cropped/ronaldo\\ronaldo42.png',
#   './images_dataset/cropped/ronaldo\\ronaldo43.png',
#   './images_dataset/cropped/ronaldo\\ronaldo44.png',
#   './images_dataset/cropped/ronaldo\\ronaldo45.png',
#   './images_dataset/cropped/ronaldo\\ronaldo5.png',
#   './images_dataset/cropped/ronaldo\\ronaldo6.png',
#   './images_dataset/cropped/ronaldo\\ronaldo7.png',
#   './images_dataset/cropped/ronaldo\\ronaldo8.png',
#   './images_dataset/cropped/ronaldo\\ronaldo9.png'],
#  'shakira': ['./images_dataset/cropped/shakira\\shakira1.png',
#   './images_dataset/cropped/shakira\\shakira10.png',
#   './images_dataset/cropped/shakira\\shakira11.png',
#   './images_dataset/cropped/shakira\\shakira12.png',
#   './images_dataset/cropped/shakira\\shakira13.png',
#   './images_dataset/cropped/shakira\\shakira14.png',
#   './images_dataset/cropped/shakira\\shakira15.png',
#   './images_dataset/cropped/shakira\\shakira16.png',
#   './images_dataset/cropped/shakira\\shakira17.png',
#   './images_dataset/cropped/shakira\\shakira18.png',
#   './images_dataset/cropped/shakira\\shakira19.png',
#   './images_dataset/cropped/shakira\\shakira2.png',
#   './images_dataset/cropped/shakira\\shakira20.png',
#   './images_dataset/cropped/shakira\\shakira21.png',
#   './images_dataset/cropped/shakira\\shakira22.png',
#   './images_dataset/cropped/shakira\\shakira23.png',
#   './images_dataset/cropped/shakira\\shakira24.png',
#   './images_dataset/cropped/shakira\\shakira25.png',
#   './images_dataset/cropped/shakira\\shakira26.png',
#   './images_dataset/cropped/shakira\\shakira27.png',
#   './images_dataset/cropped/shakira\\shakira28.png',
#   './images_dataset/cropped/shakira\\shakira29.png',
#   './images_dataset/cropped/shakira\\shakira3.png',
#   './images_dataset/cropped/shakira\\shakira30.png',
#   './images_dataset/cropped/shakira\\shakira31.png',
#   './images_dataset/cropped/shakira\\shakira32.png',
#   './images_dataset/cropped/shakira\\shakira33.png',
#   './images_dataset/cropped/shakira\\shakira34.png',
#   './images_dataset/cropped/shakira\\shakira35.png',
#   './images_dataset/cropped/shakira\\shakira36.png',
#   './images_dataset/cropped/shakira\\shakira37.png',
#   './images_dataset/cropped/shakira\\shakira38.png',
#   './images_dataset/cropped/shakira\\shakira39.png',
#   './images_dataset/cropped/shakira\\shakira4.png',
#   './images_dataset/cropped/shakira\\shakira40.png',
#   './images_dataset/cropped/shakira\\shakira41.png',
#   './images_dataset/cropped/shakira\\shakira42.png',
#   './images_dataset/cropped/shakira\\shakira43.png',
#   './images_dataset/cropped/shakira\\shakira44.png',
#   './images_dataset/cropped/shakira\\shakira45.png',
#   './images_dataset/cropped/shakira\\shakira46.png',
#   './images_dataset/cropped/shakira\\shakira47.png',
#   './images_dataset/cropped/shakira\\shakira48.png',
#   './images_dataset/cropped/shakira\\shakira49.png',
#   './images_dataset/cropped/shakira\\shakira5.png',
#   './images_dataset/cropped/shakira\\shakira50.png',
#   './images_dataset/cropped/shakira\\shakira51.png',
#   './images_dataset/cropped/shakira\\shakira52.png',
#   './images_dataset/cropped/shakira\\shakira53.png',
#   './images_dataset/cropped/shakira\\shakira54.png',
#   './images_dataset/cropped/shakira\\shakira55.png',
#   './images_dataset/cropped/shakira\\shakira56.png',
#   './images_dataset/cropped/shakira\\shakira57.png',
#   './images_dataset/cropped/shakira\\shakira58.png',
#   './images_dataset/cropped/shakira\\shakira59.png',
#   './images_dataset/cropped/shakira\\shakira6.png',
#   './images_dataset/cropped/shakira\\shakira60.png',
#   './images_dataset/cropped/shakira\\shakira61.png',
#   './images_dataset/cropped/shakira\\shakira62.png',
#   './images_dataset/cropped/shakira\\shakira63.png',
#   './images_dataset/cropped/shakira\\shakira64.png',
#   './images_dataset/cropped/shakira\\shakira65.png',
#   './images_dataset/cropped/shakira\\shakira66.png',
#   './images_dataset/cropped/shakira\\shakira7.png',
#   './images_dataset/cropped/shakira\\shakira8.png',
#   './images_dataset/cropped/shakira\\shakira9.png'],
#  'vijay': ['./images_dataset/cropped/vijay\\vijay1.png',
#   './images_dataset/cropped/vijay\\vijay10.png',
#   './images_dataset/cropped/vijay\\vijay11.png',
#   './images_dataset/cropped/vijay\\vijay12.png',
#   './images_dataset/cropped/vijay\\vijay13.png',
#   './images_dataset/cropped/vijay\\vijay14.png',
#   './images_dataset/cropped/vijay\\vijay15.png',
#   './images_dataset/cropped/vijay\\vijay16.png',
#   './images_dataset/cropped/vijay\\vijay17.png',
#   './images_dataset/cropped/vijay\\vijay18.png',
#   './images_dataset/cropped/vijay\\vijay19.png',
#   './images_dataset/cropped/vijay\\vijay2.png',
#   './images_dataset/cropped/vijay\\vijay20.png',
#   './images_dataset/cropped/vijay\\vijay21.png',
#   './images_dataset/cropped/vijay\\vijay22.png',
#   './images_dataset/cropped/vijay\\vijay23.png',
#   './images_dataset/cropped/vijay\\vijay24.png',
#   './images_dataset/cropped/vijay\\vijay25.png',
#   './images_dataset/cropped/vijay\\vijay26.png',
#   './images_dataset/cropped/vijay\\vijay27.png',
#   './images_dataset/cropped/vijay\\vijay28.png',
#   './images_dataset/cropped/vijay\\vijay29.png',
#   './images_dataset/cropped/vijay\\vijay3.png',
#   './images_dataset/cropped/vijay\\vijay30.png',
#   './images_dataset/cropped/vijay\\vijay31.png',
#   './images_dataset/cropped/vijay\\vijay32.png',
#   './images_dataset/cropped/vijay\\vijay33.png',
#   './images_dataset/cropped/vijay\\vijay34.png',
#   './images_dataset/cropped/vijay\\vijay35.png',
#   './images_dataset/cropped/vijay\\vijay36.png',
#   './images_dataset/cropped/vijay\\vijay37.png',
#   './images_dataset/cropped/vijay\\vijay38.png',
#   './images_dataset/cropped/vijay\\vijay39.png',
#   './images_dataset/cropped/vijay\\vijay4.png',
#   './images_dataset/cropped/vijay\\vijay40.png',
#   './images_dataset/cropped/vijay\\vijay41.png',
#   './images_dataset/cropped/vijay\\vijay42.png',
#   './images_dataset/cropped/vijay\\vijay43.png',
#   './images_dataset/cropped/vijay\\vijay44.png',
#   './images_dataset/cropped/vijay\\vijay45.png',
#   './images_dataset/cropped/vijay\\vijay46.png',
#   './images_dataset/cropped/vijay\\vijay47.png',
#   './images_dataset/cropped/vijay\\vijay48.png',
#   './images_dataset/cropped/vijay\\vijay49.png',
#   './images_dataset/cropped/vijay\\vijay5.png',
#   './images_dataset/cropped/vijay\\vijay50.png',
#   './images_dataset/cropped/vijay\\vijay51.png',
#   './images_dataset/cropped/vijay\\vijay52.png',
#   './images_dataset/cropped/vijay\\vijay53.png',
#   './images_dataset/cropped/vijay\\vijay54.png',
#   './images_dataset/cropped/vijay\\vijay55.png',
#   './images_dataset/cropped/vijay\\vijay6.png',
#   './images_dataset/cropped/vijay\\vijay7.png',
#   './images_dataset/cropped/vijay\\vijay8.png',
#   './images_dataset/cropped/vijay\\vijay9.png']}

# %%
class_dict = {}
count = 0
for influencer in influencer_file_names_dict.keys():
    class_dict[influencer]=count
    count = count+1
class_dict
# Out:
# {'elonmusk': 0, 'jackma': 1, 'ronaldo': 2, 'shakira': 3, 'vijay': 4}

# %% [markdown]
# ### Images in cropped folder can be used for model training. We will use these raw images along with wavelet transformed images to train our classifier. Let's prepare X and y now

# %%
X, y = [], []
for influencer_name, training_files in influencer_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        
        scalled_raw_img = cv2.resize(img, (32, 32)) #resized raw image
        
        img_har = w2d(img,'db1',5)
        
        scalled_img_har = cv2.resize(img_har, (32, 32)) #resized wavelet image
        
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1))) # raw color image and wavelet image are flattened
        X.append(combined_img)
        y.append(class_dict[influencer_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[228],
#        [228],
#        [228],
#        ...,
#        [  5],
#        [ 14],
#        [ 11]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
X
# Out:
# array([[228., 228., 228., ...,   5.,  14.,  11.],
#        [ 91., 108., 117., ..., 198., 222., 232.],
#        [ 40.,  44.,  51., ...,  10.,  10.,   5.],
#        ...,
#        [109., 174., 218., ...,  45.,   1.,   0.],
#        [ 65.,  89., 179., ...,   2.,   4., 251.],
#        [ 18.,  18.,  18., ...,   0., 250., 252.]])

# %% [markdown]
# ### Data cleaning process is done. Now we are ready to train our model

# %% [markdown]
# We will use SVM with rbf kernel tuned  with heuristic finetuning

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 4, gamma = "scale"))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.8157894736842105

# %%
len(X_test), len(X_train)
# Out:
# (76, 226)

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.95      0.84        20
#            1       0.69      0.69      0.69        16
#            2       0.90      0.90      0.90        10
#            3       0.94      0.81      0.87        21
#            4       0.86      0.67      0.75         9
#
#     accuracy                           0.82        76
#    macro avg       0.83      0.80      0.81        76
# weighted avg       0.83      0.82      0.82        76

# %% [markdown]
# ### Let's use GridSearch to try out different models with different paramets. Goal is to come up with best model with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
#                  model  best_score  \
# 0                  svm    0.836232
# 1        random_forest    0.597778
# 2  logistic_regression    0.854106
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 5}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=5, multi_class='auto',
#                                      solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.8947368421052632

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.6710526315789473

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8552631578947368

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
print(cm)
# Out:
# [[19  0  0  1  0]
#  [ 2 13  0  1  0]
#  [ 0  0  9  1  0]
#  [ 0  0  0 21  0]
#  [ 2  0  1  0  6]]

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'elonmusk': 0, 'jackma': 1, 'ronaldo': 2, 'shakira': 3, 'vijay': 4}

# %% [markdown]
# ### Save the trained model

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (1.3.2)
# ['saved_model.pkl']

# %% [markdown]
# ### Save class dictionary

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
